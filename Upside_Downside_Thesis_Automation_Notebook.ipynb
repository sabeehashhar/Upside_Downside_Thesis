# %% [markdown]
# # Upside Thesis / Downside Thesis Automation Notebook
#
# This notebook automates the generation of **Upside Thesis / Downside Thesis** summaries for US companies using:
#
# - An Excel-based extraction framework which are essential attributes around which oytput needs to be generated
# - Excel file has name of dimensions, associated prompts, keywords and semnatic search queries to filter relevant pages from 10-K & 10-Q
# - Company 10-K and 10-Q filings (PDF)
# - LLM (Semantic Search, filing-grounded)
#
# ## Two-Step Process:
#
# **Step 1 (Per Dimension):**
# - Split PDF by pages
# - Filter pages by keywords to identify relevant sections which can go to Semnatic Search
# - Further filter pages by Semantic Search so ony relavant 10 pages are fed to LLM
# - Extract facts from 10-K/10-Q filings based on dimesion prompts in the excel
# - Generate Upside Thesis and Downside Thesis interpretations with intensity ratings (High/Medium/Low)
# - Returns JSON with facts, upside_thesis, and downside_thesis arrays
#
# **Step 2 (Final Summary):**
# - Synthesize all N dimension JSONs into a cohesive Equity Analyst summary
# - Prioritize high-intensity points
# - Output professional Upside Thesis / Downside Thesis narrative

# %% [markdown]
# ## 1. Install & Import Dependencies

# %%
# %pip install pandas openpyxl pypdf azure-identity azure-ai-openai langchain

# %%
import os
import json
import pandas as pd
from pypdf import PdfReader
from typing import Dict, List
import numpy as np

# %% [markdown]
# ## 2. Configuration (PLACEHOLDERS)

# %%
# Azure OpenAI Configuration
AZURE_OPENAI_ENDPOINT='https://your-resource.openai.azure.com'
AZURE_OPENAI_API_KEY='your-api-key-here'
AZURE_API_VERSION='2024-02-15-preview'
AZURE_DEPLOYMENT_NAME='your-gpt4-deployment-name'
AZURE_EMBEDDING_DEPLOYMENT='your-embedding-deployment-name'

FRAMEWORK_EXCEL_PATH = "Upside_Downside_Thesis_10K_10Q_Extraction_Framework.xlsx"
FILINGS_DIR = "./SEC_Filings"
OUTPUT_DIR = "./output"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Global embedding cache to avoid recomputation
EMBEDDING_CACHE = {}

# Global tracking metrics
METRICS = {
    'llm_calls': 0,
    'embedding_calls': 0,
    'total_tokens': 0,
    'prompt_tokens': 0,
    'completion_tokens': 0,
    'embedding_tokens': 0,
    'start_time': None,
    'end_time': None
}

# %% [markdown]
# ## 3. Load Upside/Downside Thesis Extraction Framework

# %%
framework_df = pd.read_excel(FRAMEWORK_EXCEL_PATH)
framework_df.head(20)
# Out:
#                                     Dimension  \
# 0       Business Model & Competitive Position
# 1     Revenue Growth Drivers & Demand Outlook
# 2             Pricing Power & Revenue Quality
# 3                    Margins & Cost Structure
# 4                        Cash Flow Generation
# 5  Capital Allocation & Investment Discipline
# 6          Balance Sheet Strength & Liquidity
# 7            Operational & Supply Chain Risks
# 8         Market, Macro & Regulatory Exposure
# 9             Management Strategy & Execution
#
#                                    Extraction Prompt  \
# 0  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
# 1  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
# 2  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
# 3  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
# 4  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
# 5  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
# 6  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
# 7  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
# 8  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
# 9  Task:\n\nStep 1 – Fact Extraction: \nExtract v...
#
#                                       Keyword_Filter  \
# 0  business model, core operations, operating mod...
# 1  revenue drivers, demand trends, backlog, booki...
# 2  pricing power, price increases, pricing action...
# 3  gross margin, operating margin, operating inco...
# 4  operating cash flow, free cash flow, cash conv...
# 5  capital allocation, investment priorities, acq...
# 6  balance sheet, liquidity position, leverage, d...
# 7  supply chain disruption, operational risk, cap...
# 8  macroeconomic conditions, interest rates, infl...
# 9  management strategy, strategic priorities, exe...
#
#                                       Semantic_Query  Min_Relevant_Pages
# 0  How the company describes its business model, ...                   3
# 1  What factors management identifies as driving ...                   3
# 2  What factors management identifies as driving ...                   2
# 3  What factors management cites as affecting gro...                   2
# 4  How management describes capital allocation pr...                   2
# 5  How management describes capital allocation pr...                   2
# 6  How management discusses liquidity, cash gener...                   2
# 7  Material risks management identifies that coul...                   2
# 8  What management discloses about this dimension...                   2
# 9  What management discloses about this dimension...                   2

# %% [markdown]
# ## 4. PDF Parsing Utilities

# %%
def extract_text_from_pdf(pdf_path: str) -> List[Dict]:
    """
    Extract text from PDF at PAGE LEVEL with metadata.
    Returns list of dicts: [{'page_num': int, 'text': str, 'filing_type': str}, ...]
    """
    reader = PdfReader(pdf_path)
    pages = []
    
    # Infer filing type from filename
    filing_type = "Unknown"
    if "10-K" in pdf_path:
        filing_type = "10-K"
    elif "10-Q" in pdf_path:
        filing_type = "10-Q"
    
    for page_num, page in enumerate(reader.pages, start=1):
        text = page.extract_text()
        if text:
            pages.append({
                'page_num': page_num,
                'text': text,
                'filing_type': filing_type
            })
    
    return pages

# %%
def filter_pages_by_keywords(pages: List[Dict], keywords: str) -> List[Dict]:
    """
    Filter pages containing ANY keyword from the comma-separated list (case-insensitive).
    Returns filtered pages with metadata intact.
    """
    if not keywords or keywords.strip() == "":
        return pages
    
    keyword_list = [kw.strip().lower() for kw in keywords.split(',') if kw.strip()]
    
    filtered = []
    for page in pages:
        page_text_lower = page['text'].lower()
        if any(kw in page_text_lower for kw in keyword_list):
            filtered.append(page)
    
    return filtered


def embed_texts_with_azure_openai(texts: List[str], max_retries: int = 3) -> List[List[float]]:
    """
    Generate embeddings using Azure OpenAI.
    Uses EMBEDDING_CACHE to avoid recomputation.
    Implements retry logic with exponential backoff for rate limit errors.
    """
    from openai import AzureOpenAI
    import time
    
    client = AzureOpenAI(
        api_key=AZURE_OPENAI_API_KEY,
        api_version=AZURE_API_VERSION,
        azure_endpoint=AZURE_OPENAI_ENDPOINT
    )
    
    embeddings = []
    texts_to_embed = []
    cached_indices = []
    
    # Check cache
    for i, text in enumerate(texts):
        text_hash = hash(text)
        if text_hash in EMBEDDING_CACHE:
            embeddings.append(EMBEDDING_CACHE[text_hash])
            cached_indices.append(i)
        else:
            texts_to_embed.append((i, text, text_hash))
    
    # Embed uncached texts with retry logic
    if texts_to_embed:
        batch_texts = [t[1] for t in texts_to_embed]
        
        for attempt in range(max_retries):
            try:
                response = client.embeddings.create(
                    model=AZURE_EMBEDDING_DEPLOYMENT,
                    input=batch_texts
                )
                
                # Track embedding call
                METRICS['embedding_calls'] += 1
                METRICS['embedding_tokens'] += response.usage.total_tokens
                
                for idx, (original_idx, text, text_hash) in enumerate(texts_to_embed):
                    embedding = response.data[idx].embedding
                    EMBEDDING_CACHE[text_hash] = embedding
                    embeddings.insert(original_idx, embedding)
                
                return embeddings
                
            except Exception as e:
                error_str = str(e)
                
                # Check if it's a rate limit error (429)
                if "429" in error_str or "RateLimitReached" in error_str:
                    wait_time = (2 ** attempt) * 15  # 15s, 30s, 60s
                    print(f"⚠️  Rate limit hit. Waiting {wait_time}s before retry {attempt + 1}/{max_retries}...")
                    time.sleep(wait_time)
                    continue
                else:
                    print(f"❌ Error generating embeddings: {e}")
                    print(f"⚠️  Falling back to zero vectors - semantic search will be ineffective!")
                    return [[0.0] * 1536 for _ in texts]
        
        # If all retries exhausted
        print(f"❌ Rate limit retries exhausted after {max_retries} attempts.")
        print(f"⚠️  Semantic search will use arbitrary pages instead of semantically relevant ones!")
        return [[0.0] * 1536 for _ in texts]
    
    return embeddings


def cosine_similarity(vec1: List[float], vec2: List[float]) -> float:
    """Compute cosine similarity between two vectors."""
    vec1 = np.array(vec1)
    vec2 = np.array(vec2)
    
    norm1 = np.linalg.norm(vec1)
    norm2 = np.linalg.norm(vec2)
    
    if norm1 == 0 or norm2 == 0:
        return 0.0
    
    return np.dot(vec1, vec2) / (norm1 * norm2)


def retrieve_top_k_pages_by_embedding(
    pages: List[Dict], 
    semantic_query: str, 
    k: int = 15
) -> List[Dict]:
    """
    Retrieve top-k pages by semantic similarity using Azure OpenAI embeddings.
    Computes cosine similarity between query and page embeddings.
    """
    if not pages:
        return []
    
    # Generate embeddings
    page_texts = [p['text'] for p in pages]
    all_texts = [semantic_query] + page_texts
    
    embeddings = embed_texts_with_azure_openai(all_texts)
    
    query_embedding = embeddings[0]
    page_embeddings = embeddings[1:]
    
    # Compute similarity scores
    scores = []
    for i, page_emb in enumerate(page_embeddings):
        similarity = cosine_similarity(query_embedding, page_emb)
        scores.append((similarity, i))
    
    # Sort by similarity (descending) and take top-k
    scores.sort(reverse=True, key=lambda x: x[0])
    top_k_indices = [idx for _, idx in scores[:k]]
    
    # Return top-k pages with similarity scores
    top_pages = []
    for score, idx in scores[:k]:
        page = pages[idx].copy()
        page['similarity_score'] = score
        top_pages.append(page)
    
    return top_pages


def should_skip_dimension(pages: List[Dict], min_pages: int) -> bool:
    """
    Check if dimension should be skipped due to insufficient evidence.
    """
    return len(pages) < min_pages


def build_dimension_context(pages: List[Dict]) -> str:
    """
    Build dimension-scoped context from retrieved pages.
    Format: [Filing Type - Page N]\n{text}\n\n
    """
    if not pages:
        return ""
    
    context_parts = []
    for page in pages:
        header = f"[{page['filing_type']} - Page {page['page_num']}]"
        context_parts.append(f"{header}\n{page['text']}")
    
    return "\n\n".join(context_parts)

# %% [markdown]
# ## 5. Retrieval and Filtering Layer (RAG + Hallucination Prevention)
#
# This section implements:
# - Keyword-based filtering
# - Semantic vector search using Azure OpenAI embeddings
# - Cosine similarity ranking
# - Context building from relevant pages

# %% [markdown]
# ## 6. Load Company Filings

# %%
def load_company_filings(ticker: str) -> Dict[str, List[Dict]]:
    """
    Load 10-K and 10-Q filings for a given ticker at PAGE LEVEL.
    Returns: {'10-K': [page_dicts], '10-Q': [page_dicts]}
    Each page_dict: {'page_num': int, 'text': str, 'filing_type': str}
    """
    import glob
    
    filings = {}
    
    # Find 10-K files (may have dates in filename)
    ten_k_pattern = os.path.join(FILINGS_DIR, f"{ticker}_10-K*.pdf")
    ten_k_files = glob.glob(ten_k_pattern)
    if ten_k_files:
        filings['10-K'] = extract_text_from_pdf(ten_k_files[0])
    
    # Find 10-Q files (may have dates in filename)
    ten_q_pattern = os.path.join(FILINGS_DIR, f"{ticker}_10-Q*.pdf")
    ten_q_files = glob.glob(ten_q_pattern)
    if ten_q_files:
        filings['10-Q'] = extract_text_from_pdf(ten_q_files[0])
    
    return filings

# %% [markdown]
# ## 7. Azure OpenAI Call (PLACEHOLDER)

# %%
def call_azure_openai(prompt: str, context: str) -> str:
    """
    Call Azure OpenAI with the given prompt and context.
    """
    from openai import AzureOpenAI
    
    client = AzureOpenAI(
        api_key=AZURE_OPENAI_API_KEY,
        api_version=AZURE_API_VERSION,
        azure_endpoint=AZURE_OPENAI_ENDPOINT
    )
    
    # Combine prompt and context into messages
    messages = [
        {"role": "system", "content": "You are a financial analyst assistant that extracts information from SEC filings."},
        {"role": "user", "content": f"{prompt}\n\nContext:\n{context}"}
    ]
    
    try:
        response = client.chat.completions.create(
            model=AZURE_DEPLOYMENT_NAME,
            messages=messages,
            temperature=0.1,
            max_tokens=4000
        )
        
        # Track LLM call and tokens
        METRICS['llm_calls'] += 1
        METRICS['prompt_tokens'] += response.usage.prompt_tokens
        METRICS['completion_tokens'] += response.usage.completion_tokens
        METRICS['total_tokens'] += response.usage.total_tokens
        
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error calling Azure OpenAI: {e}")
        return "{\"facts\": [], \"upside_thesis\": [], \"downside_thesis\": []}"

# %% [markdown]
# ## 8. Step 1: Dimension Extraction with Retrieval
#
# Extracts facts and generates Upside/Downside Thesis interpretations for each dimension using:
# - Keyword filtering and semantic search
# - Intensity ratings (High/Medium/Low)

# %%
def run_dimension_extraction(row, filings_pages: Dict[str, List[Dict]], dimension_num: int = 0, ticker: str = "") -> Dict:
    """
    Step 1: Extract facts and generate Upside/Downside Thesis interpretations with intensity.
    NOW WITH RETRIEVAL LAYER to prevent hallucinations.
    Returns JSON with facts, upside_thesis, and downside_thesis arrays.
    """
    dimension_name = row['Dimension']
    prompt = row['Extraction Prompt']
    
    # Read retrieval configuration from framework
    keyword_filter = row.get('Keyword_Filter', '')
    semantic_query = row.get('Semantic_Query', '')
    min_relevant_pages = int(row.get('Min_Relevant_Pages', 3))
    
    print(f"\n{'='*80}")
    print(f"Running Dimension {dimension_num}: {dimension_name} for {ticker} company")
    print(f"{'='*80}")
    print(f"Retrieval Config:")
    print(f"  - Keyword Filter: {keyword_filter[:100]}...")
    print(f"  - Semantic Query: {semantic_query[:100]}...")
    print(f"  - Min Relevant Pages: {min_relevant_pages}")
    
    # Combine all pages from all filings
    all_pages = []
    for filing_type, pages in filings_pages.items():
        all_pages.extend(pages)
    
    print(f"\nTotal pages available: {len(all_pages)}")
    
    # STEP 1: Keyword filtering
    print(f"Applying keyword filter...")
    filtered_pages = filter_pages_by_keywords(all_pages, keyword_filter)
    print(f"Pages after keyword filter: {len(filtered_pages)}")
    
    if not filtered_pages:
        print(f"⚠️ No pages matched keywords. Skipping dimension.")
        return {
            "dimension": dimension_name,
            "facts": [],
            "upside_thesis": [{"interpretation": "Insufficient disclosure for this dimension.", "intensity": "N/A"}],
            "downside_thesis": [{"interpretation": "Insufficient disclosure for this dimension.", "intensity": "N/A"}]
        }
    
    # STEP 2: Semantic vector search
    print(f"Performing semantic vector search...")
    top_pages = retrieve_top_k_pages_by_embedding(filtered_pages, semantic_query, k=10)
    print(f"Top-k pages selected: {len(top_pages)}")
    
    if top_pages:
        scores_str = [f"{p['similarity_score']:.3f}" for p in top_pages[:3]]
        print(f"Similarity scores: {scores_str}")
    
    # STEP 3: Hallucination guardrail
    if should_skip_dimension(top_pages, min_relevant_pages):
        print(f"⚠️ Insufficient pages ({len(top_pages)} < {min_relevant_pages}). Skipping LLM call.")
        return {
            "dimension": dimension_name,
            "facts": [],
            "upside_thesis": [{"interpretation": "Insufficient disclosure for this dimension.", "intensity": "N/A"}],
            "downside_thesis": [{"interpretation": "Insufficient disclosure for this dimension.", "intensity": "N/A"}]
        }
    
    # STEP 4: Build dimension-scoped context
    context = build_dimension_context(top_pages)
    
    print(f"\nContext built (length: {len(context)} characters)")
    pages_info = [f"{p['filing_type']}-P{p['page_num']}" for p in top_pages]
    print(f"Pages included: {pages_info}")
    
    # STEP 5: Modify prompt with hallucination prevention instructions
    enhanced_prompt = prompt + "\n\n" + "Use ONLY the provided excerpts. Do NOT infer beyond them."
    
    print(f"\nCalling Azure OpenAI with enhanced prompt...")
    
    response = call_azure_openai(enhanced_prompt, context)
    
    print(f"\nResponse received (length: {len(response)} chars)")
    print(f"Response preview:\n{response[:300]}...")
    
    # Parse JSON response from LLM
    try:
        parsed = json.loads(response)
        
        # Handle case where LLM returns nested JSON string
        if isinstance(parsed, str):
            print("⚠️ Response was a JSON string, attempting to parse again...")
            parsed = json.loads(parsed)
        
        # Verify it's a dictionary
        if not isinstance(parsed, dict):
            raise ValueError(f"Expected dict, got {type(parsed)}")
        
        num_facts = len(parsed.get('facts', []))
        num_upside = len(parsed.get('upside_thesis', []))
        num_downside = len(parsed.get('downside_thesis', []))
        print(f"\n✓ Successfully parsed JSON:")
        print(f"  - Facts extracted: {num_facts}")
        print(f"  - Upside Thesis points: {num_upside}")
        print(f"  - Downside Thesis points: {num_downside}")
        return parsed
    except (json.JSONDecodeError, ValueError) as e:
        print(f"\n✗ JSON parsing failed: {e}")
        print(f"Response type: {type(response)}")
        print(f"Response content: {response[:500]}")
        print(f"Returning empty result for dimension: {dimension_name}")
        # Fallback if JSON parsing fails
        return {
            "facts": [],
            "upside_thesis": [],
            "downside_thesis": []
        }

# %% [markdown]
# ## 9. Step 2: Final Summary Generation
#
# Synthesizes all dimension JSONs into a cohesive Equity Analyst style analyst summary with separate Upside Thesis and Downside Thesis sections.

# %%
def generate_final_summary(ticker: str, all_dimensions_data: List[Dict]) -> Dict[str, str]:
    """
    Step 2: Generate final  Equity style analyst summary from all dimension extractions.
    Takes the JSON output from Step 1 for all N dimensions and synthesizes it.
    """
    
    # Prepare the consolidated JSON from all dimensions
    dimensions_summary = json.dumps(all_dimensions_data, indent=2)
    
    synthesis_prompt = f"""
You are a Equity Analyst writing an Upside Thesis / Downside Thesis summary for {ticker}.

Below is the complete JSON output from filing-grounded analysis across all investment dimensions:

{dimensions_summary}

Task:
Write a concise, professional Upside Thesis / Downside Thesis summary as it would appear in equity research report. 

UPSIDE THESIS:
- Format as BULLET POINTS using markdown (• or -)
- Order points by DECREASING IMPORTANCE: High intensity first, then Medium, then Low
- Synthesize the optimistic interpretations across all dimensions
- Write in the voice of an Equity analyst
- Use only the interpretations provided in the JSON
- Keep it concise (3-5 key points)
- Each bullet point should be a complete, clear statement

DOWNSIDE THESIS:
- Format as BULLET POINTS using markdown (• or -)
- Order points by DECREASING IMPORTANCE: High intensity first, then Medium, then Low
- Synthesize the cautious interpretations across all dimensions
- Write in the voice of an Equity analyst
- Use only the interpretations provided in the JSON
- Keep it concise (3-5 key points)
- Each bullet point should be a complete, clear statement

Rules:
- MUST use bullet point format (start each point with • or -)
- Do NOT add facts not present in the JSON
- Do NOT make forecasts or valuations
- Maintain professional, analytical tone
- If a dimension has "Not disclosed", acknowledge gaps where material
- STRICTLY order by intensity: High → Medium → Low

Output Format:
UPSIDE THESIS:
• [High intensity point 1]
• [High intensity point 2]
• [Medium intensity point]
...

DOWNSIDE THESIS:
• [High intensity point 1]
• [High intensity point 2]
• [Medium intensity point]
...
"""
    
    output = call_azure_openai(synthesis_prompt, dimensions_summary)
    
    # Parse the output to separate Upside Thesis and Downside Thesis sections
    upside_summary = ""
    downside_summary = ""
    
    # Try to split by common section headers
    if "UPSIDE THESIS" in output.upper() and "DOWNSIDE THESIS" in output.upper():
        # Find the positions of the headers (case-insensitive)
        import re
        upside_match = re.search(r'UPSIDE THESIS:?', output, re.IGNORECASE)
        downside_match = re.search(r'DOWNSIDE THESIS:?', output, re.IGNORECASE)
        
        if upside_match and downside_match:
            # Extract text between UPSIDE THESIS and DOWNSIDE THESIS
            upside_start = upside_match.end()
            downside_start = downside_match.start()
            upside_summary = output[upside_start:downside_start].strip()
            
            # Extract text after DOWNSIDE THESIS
            downside_summary = output[downside_match.end():].strip()
        else:
            # Fallback: use entire output for both
            upside_summary = output
            downside_summary = output
    else:
        # Fallback: use entire output for both
        upside_summary = output
        downside_summary = output
    
    # Parse the output (expecting Upside Thesis and Downside Thesis sections)
    return {
        "upside_thesis_summary": upside_summary,
        "downside_thesis_summary": downside_summary,
        "raw_dimensions": all_dimensions_data
    }

# %% [markdown]
# ## 10. End-to-End Company Processing
#
# Main orchestration function that runs both Step 1 (dimension extraction) and Step 2 (final summary) for a given company ticker.

# %%
def process_company(ticker: str):
    """
    End-to-end processing for a single company.
    
    Step 1: Run dimension extraction for all N dimensions (returns JSON per dimension)
    Step 2: Generate final Equity-style Upside Thesis / Downside Thesis summary
    """
    import time
    
    # Reset and start tracking
    METRICS['llm_calls'] = 0
    METRICS['embedding_calls'] = 0
    METRICS['total_tokens'] = 0
    METRICS['prompt_tokens'] = 0
    METRICS['completion_tokens'] = 0
    METRICS['embedding_tokens'] = 0
    METRICS['start_time'] = time.time()
    
    # Load company filings
    filings = load_company_filings(ticker)
    
    # Step 1: Run extraction for all dimensions
    all_dimensions_data = []
    for dim_idx, (_, row) in enumerate(framework_df.iterrows(), start=1):
        dimension_name = row['Dimension']
        extracted = run_dimension_extraction(row, filings, dimension_num=dim_idx, ticker=ticker)
        
        # Add dimension name to the extracted data
        extracted['dimension'] = dimension_name
        all_dimensions_data.append(extracted)
    
    # Step 2: Generate final summary from all dimensions
    final_summary = generate_final_summary(ticker, all_dimensions_data)
    
    # End tracking
    METRICS['end_time'] = time.time()
    
    return final_summary

# %% [markdown]
# ## 11. Save Results
#
# Saves analysis results as JSON and Excel files with:
# - Final Summary sheet (Upside/Downside Thesis)
# - Dimension Details sheet (per-dimension facts and interpretations)

# %%
def save_results(ticker: str, results: Dict):
    """Save results as both JSON and Excel files"""
    # Save JSON
    json_file = os.path.join(OUTPUT_DIR, f"{ticker}_upside_downside_thesis.json")
    with open(json_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)
    
    # Save Excel with multiple sheets
    excel_file = os.path.join(OUTPUT_DIR, f"{ticker}_upside_downside_thesis.xlsx")
    with pd.ExcelWriter(excel_file, engine='openpyxl') as writer:
        # Sheet 1: Final Summary
        # Handle both single string and dict with numeric keys (old format)
        upside_summary = results['upside_thesis_summary']
        downside_summary = results['downside_thesis_summary']
        
        # If old format (dict with numeric keys), get the first entry
        if isinstance(upside_summary, dict):
            upside_summary = upside_summary.get('0', upside_summary.get(0, str(upside_summary)))
        if isinstance(downside_summary, dict):
            downside_summary = downside_summary.get('0', downside_summary.get(0, str(downside_summary)))
        
        summary_data = {
            'Section': ['Upside Thesis', 'Downside Thesis'],
            'Summary': [upside_summary, downside_summary]
        }
        df_summary = pd.DataFrame(summary_data)
        df_summary.to_excel(writer, sheet_name='Final Summary', index=False)
        
        # Sheet 2: Dimension Details
        dimension_rows = []
        
        # Handle both list format (new) and dict format with numeric keys (old)
        raw_dims = results['raw_dimensions']
        if isinstance(raw_dims, dict):
            # Old format: convert dict with numeric keys to list
            dimensions_list = [raw_dims[str(i)] for i in range(len(raw_dims))]
        else:
            # New format: already a list
            dimensions_list = raw_dims
        
        for dim in dimensions_list:
            # Extract facts
            facts_text = "\n\n".join([f"• {f['statement']} (Source: {f['source_section']})" 
                                      for f in dim.get('facts', [])])
            
            # Extract upside thesis
            upside_text = "\n\n".join([f"[{b['intensity']}] {b['interpretation']}" 
                                      for b in dim.get('upside_thesis', [])])
            
            # Extract downside thesis
            downside_text = "\n\n".join([f"[{b['intensity']}] {b['interpretation']}" 
                                      for b in dim.get('downside_thesis', [])])
            
            dimension_rows.append({
                'Dimension': dim.get('dimension', ''),
                'Facts Extracted': facts_text if facts_text else 'No facts extracted',
                'Upside Thesis': upside_text if upside_text else 'No upside points',
                'Downside Thesis': downside_text if downside_text else 'No downside points'
            })
        
        df_dimensions = pd.DataFrame(dimension_rows)
        df_dimensions.to_excel(writer, sheet_name='Dimension Details', index=False)
        
        # Adjust column widths
        for sheet_name in writer.sheets:
            worksheet = writer.sheets[sheet_name]
            for column in worksheet.columns:
                max_length = 0
                column_letter = column[0].column_letter
                for cell in column:
                    try:
                        if len(str(cell.value)) > max_length:
                            max_length = len(str(cell.value))
                    except:
                        pass
                adjusted_width = min(max_length + 2, 100)
                worksheet.column_dimensions[column_letter].width = adjusted_width
    
    print(f"\n{'='*80}")
    print(f"✓ Saved JSON to: {json_file}")
    print(f"✓ Saved Excel to: {excel_file}")
    print(f"{'='*80}")

# %%
def print_usage_metrics(ticker: str = None, save_to_file: bool = True):
    """
    Display comprehensive usage metrics and cost estimates.
    Optionally save to output files.
    
    Pricing (as of Dec 2025):
    - GPT-4.1 Mini: $0.30/1M input tokens, $1.20/1M output tokens
    - text-embedding-3-small: $0.02/1M tokens
    
    Args:
        ticker: Company ticker symbol (for filename)
        save_to_file: If True, saves metrics to JSON and TXT files
    """
    if METRICS['start_time'] is None:
        print("No metrics available. Run process_company() first.")
        return
    
    # Calculate duration
    duration = METRICS['end_time'] - METRICS['start_time']
    minutes = int(duration // 60)
    seconds = int(duration % 60)
    
    # Calculate costs (Azure OpenAI pricing)
    llm_input_cost = (METRICS['prompt_tokens'] / 1_000_000) * 0.30
    llm_output_cost = (METRICS['completion_tokens'] / 1_000_000) * 1.20
    embedding_cost = (METRICS['embedding_tokens'] / 1_000_000) * 0.02
    total_cost = llm_input_cost + llm_output_cost + embedding_cost
    
    # Build metrics dictionary
    metrics_data = {
        'ticker': ticker,
        'timestamp': pd.Timestamp.now().isoformat(),
        'api_calls': {
            'llm_calls': METRICS['llm_calls'],
            'embedding_calls': METRICS['embedding_calls'],
            'total_api_calls': METRICS['llm_calls'] + METRICS['embedding_calls']
        },
        'token_usage': {
            'prompt_tokens': METRICS['prompt_tokens'],
            'completion_tokens': METRICS['completion_tokens'],
            'embedding_tokens': METRICS['embedding_tokens'],
            'total_llm_tokens': METRICS['total_tokens'],
            'grand_total_tokens': METRICS['total_tokens'] + METRICS['embedding_tokens']
        },
        'execution_time': {
            'duration_seconds': round(duration, 1),
            'duration_formatted': f"{minutes}m {seconds}s",
            'avg_per_llm_call_seconds': round(duration / METRICS['llm_calls'], 1)
        },
        'costs_usd': {
            'llm_input': round(llm_input_cost, 4),
            'llm_output': round(llm_output_cost, 4),
            'embeddings': round(embedding_cost, 4),
            'total_cost': round(total_cost, 4)
        },
        'efficiency': {
            'embedding_cache_hits': len(EMBEDDING_CACHE),
            'tokens_per_llm_call': round(METRICS['total_tokens'] / METRICS['llm_calls'], 0),
            'cost_per_llm_call': round((llm_input_cost + llm_output_cost) / METRICS['llm_calls'], 4)
        }
    }
    
    # Print to console
    print(f"\n{'='*80}")
    print(f"USAGE METRICS & COST SUMMARY")
    print(f"{'='*80}")
    print(f"\n📊 API CALLS:")
    print(f"  • LLM Calls (Chat):        {METRICS['llm_calls']}")
    print(f"  • Embedding Calls:         {METRICS['embedding_calls']}")
    print(f"  • Total API Calls:         {METRICS['llm_calls'] + METRICS['embedding_calls']}")
    
    print(f"\n🔢 TOKEN USAGE:")
    print(f"  • Prompt Tokens:           {METRICS['prompt_tokens']:,}")
    print(f"  • Completion Tokens:       {METRICS['completion_tokens']:,}")
    print(f"  • Embedding Tokens:        {METRICS['embedding_tokens']:,}")
    print(f"  • Total LLM Tokens:        {METRICS['total_tokens']:,}")
    print(f"  • Grand Total Tokens:      {METRICS['total_tokens'] + METRICS['embedding_tokens']:,}")
    
    print(f"\n⏱️  EXECUTION TIME:")
    print(f"  • Total Duration:          {minutes}m {seconds}s ({duration:.1f}s)")
    print(f"  • Avg per LLM Call:        {duration / METRICS['llm_calls']:.1f}s")
    
    print(f"\n💰 ESTIMATED COST (Azure OpenAI):")
    print(f"  • LLM Input:               ${llm_input_cost:.4f}")
    print(f"  • LLM Output:              ${llm_output_cost:.4f}")
    print(f"  • Embeddings:              ${embedding_cost:.4f}")
    print(f"  • TOTAL COST:              ${total_cost:.4f}")
    
    print(f"\n📈 EFFICIENCY METRICS:")
    print(f"  • Embedding Cache Hits:    {len(EMBEDDING_CACHE)} unique texts cached")
    print(f"  • Tokens per LLM Call:     {METRICS['total_tokens'] / METRICS['llm_calls']:.0f} avg")
    print(f"  • Cost per LLM Call:       ${(llm_input_cost + llm_output_cost) / METRICS['llm_calls']:.4f} avg")
    
    print(f"{'='*80}\n")
    
    # Save to files if requested
    if save_to_file:
        # Generate filenames
        ticker_prefix = f"{ticker}_" if ticker else ""
        timestamp = pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")
        
        # Save readable text file only (no JSON)
        txt_filename = os.path.join(OUTPUT_DIR, f"{ticker_prefix}usage_metrics_{timestamp}.txt")
        with open(txt_filename, 'w', encoding='utf-8') as f:
            f.write("="*80 + "\n")
            f.write(f"USAGE METRICS & COST SUMMARY - {ticker or 'Unknown Ticker'}\n")
            f.write(f"Generated: {metrics_data['timestamp']}\n")
            f.write("="*80 + "\n\n")
            
            f.write("API CALLS:\n")
            f.write(f"  • LLM Calls (Chat):        {METRICS['llm_calls']}\n")
            f.write(f"  • Embedding Calls:         {METRICS['embedding_calls']}\n")
            f.write(f"  • Total API Calls:         {METRICS['llm_calls'] + METRICS['embedding_calls']}\n\n")
            
            f.write("TOKEN USAGE:\n")
            f.write(f"  • Prompt Tokens:           {METRICS['prompt_tokens']:,}\n")
            f.write(f"  • Completion Tokens:       {METRICS['completion_tokens']:,}\n")
            f.write(f"  • Embedding Tokens:        {METRICS['embedding_tokens']:,}\n")
            f.write(f"  • Total LLM Tokens:        {METRICS['total_tokens']:,}\n")
            f.write(f"  • Grand Total Tokens:      {METRICS['total_tokens'] + METRICS['embedding_tokens']:,}\n\n")
            
            f.write("EXECUTION TIME:\n")
            f.write(f"  • Total Duration:          {minutes}m {seconds}s ({duration:.1f}s)\n")
            f.write(f"  • Avg per LLM Call:        {duration / METRICS['llm_calls']:.1f}s\n\n")
            
            f.write("ESTIMATED COST (Azure OpenAI):\n")
            f.write(f"  • LLM Input:               ${llm_input_cost:.4f}\n")
            f.write(f"  • LLM Output:              ${llm_output_cost:.4f}\n")
            f.write(f"  • Embeddings:              ${embedding_cost:.4f}\n")
            f.write(f"  • TOTAL COST:              ${total_cost:.4f}\n\n")
            
            f.write("EFFICIENCY METRICS:\n")
            f.write(f"  • Embedding Cache Hits:    {len(EMBEDDING_CACHE)} unique texts cached\n")
            f.write(f"  • Tokens per LLM Call:     {METRICS['total_tokens'] / METRICS['llm_calls']:.0f} avg\n")
            f.write(f"  • Cost per LLM Call:       ${(llm_input_cost + llm_output_cost) / METRICS['llm_calls']:.4f} avg\n")
            f.write("="*80 + "\n")
        
        print(f"💾 Metrics saved to: {txt_filename}\n")
    
    return metrics_data

# %% [markdown]
# ## 13. Run Analysis for Companies
#
# Execute the complete analysis pipeline for multiple company tickers and display results.

# %% [markdown]
# ## 12. Usage Metrics and Cost Tracking
#
# Tracks and reports:
# - API call counts (LLM + embeddings)
# - Token usage and costs
# - Execution time and efficiency metrics

# %%
ticker_list=['BLDR','CEG','CSW','DOCN','FTAI','LSCC','TRGP']
#ticker_list=['BLDR']
for ticker in ticker_list:
    results = process_company(ticker)
    save_results(ticker, results)
    # Display usage metrics and save to files
    metrics = print_usage_metrics(ticker=ticker, save_to_file=True)
    # Display the final summary
    print("\n" + "="*80)
    print("FINAL UPSIDE THESIS / DOWNSIDE THESIS SUMMARY")
    print("="*80)
    print("\n📈 UPSIDE THESIS:")
    print("-" * 80)
    print(results['upside_thesis_summary'])
    print("\n📉 DOWNSIDE THESIS:")
    print("-" * 80)
    print(results['downside_thesis_summary'])
# Out:
# ================================================================================
# Running Dimension 1: Business Model & Competitive Position for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: business model, core operations, operating model, revenue model, asset portfolio, operating assets, ...
#   - Semantic Query: How the company describes its business model, competitive advantages, scale, customer value proposit...
#   - Min Relevant Pages: 3
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 11
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.469', '0.460', '0.411']
#
# Context built (length: 51780 characters)
# Pages included: ['10-K-P12', '10-K-P10', '10-K-P22', '10-K-P18', '10-K-P44', '10-K-P26', '10-K-P20', '10-Q-P29', '10-Q-P31', '10-K-P56']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 11725 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Our strategy is to attract and retain customers through exceptional customer service, leading product quality, broad product and service offerings, and competitive pricing. This strategy is centered on building and maintaining strong customer relationships ra...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 16
#   - Upside Thesis points: 6
#   - Downside Thesis points: 6
#
# ================================================================================
# Running Dimension 2: Revenue Growth Drivers & Demand Outlook for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: revenue drivers, demand trends, backlog, bookings, pipeline visibility, organic growth, customer dem...
#   - Semantic Query: What factors management identifies as driving or constraining growth, including demand trends, prici...
#   - Min Relevant Pages: 3
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 6
# Performing semantic vector search...
# Top-k pages selected: 6
# Similarity scores: ['0.443', '0.411', '0.409']
#
# Context built (length: 34761 characters)
# Pages included: ['10-K-P22', '10-K-P52', '10-K-P26', '10-K-P10', '10-Q-P27', '10-K-P8']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 8712 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Our long-term strategy depends in part on growing our sales of prefabricated components and other value-added products, increasing our market share, and implementing various initiatives to increase our operational efficiency, improve our margins, optimize our...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 12
#   - Upside Thesis points: 4
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 3: Pricing Power & Revenue Quality for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: pricing power, price increases, pricing actions, contract terms, recurring revenue, customer mix, re...
#   - Semantic Query: What factors management identifies as driving or constraining top-line growth, including demand, pri...
#   - Min Relevant Pages: 2
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 5
# Performing semantic vector search...
# Top-k pages selected: 5
# Similarity scores: ['0.418', '0.408', '0.380']
#
# Context built (length: 21287 characters)
# Pages included: ['10-K-P52', '10-K-P26', '10-K-P62', '10-Q-P36', '10-K-P76']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 4207 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Short-term changes in the cost and/or availability of these materials, some of which are subject to significant fluctuations, are often passed on to our customers, but our pricing quotation periods and market competition may limit our ability to pass on such ...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 6
#   - Upside Thesis points: 3
#   - Downside Thesis points: 3
#
# ================================================================================
# Running Dimension 4: Margins & Cost Structure for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: gross margin, operating margin, operating income, cost structure, operating expenses, cost drivers, ...
#   - Semantic Query: What factors management cites as affecting gross or operating margins, including pricing, cost infla...
#   - Min Relevant Pages: 2
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 22
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.430', '0.398', '0.391']
#
# Context built (length: 48316 characters)
# Pages included: ['10-K-P28', '10-K-P26', '10-Q-P25', '10-K-P52', '10-Q-P33', '10-K-P57', '10-K-P20', '10-K-P62', '10-K-P10', '10-K-P74']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 7346 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Gross margins on sales to single-family, multi-family, commercial and other contractors vary based on a variety of factors, including the purchase volumes of the individual customer, the mix of products sold to that customer, the cost to serve that customer, ...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 16
#   - Upside Thesis points: 3
#   - Downside Thesis points: 3
#
# ================================================================================
# Running Dimension 5: Cash Flow Generation for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: operating cash flow, free cash flow, cash conversion, working capital, capital intensity, cash gener...
#   - Semantic Query: How management describes capital allocation priorities, including acquisitions, share repurchases, d...
#   - Min Relevant Pages: 2
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 15
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.478', '0.467', '0.459']
#
# Context built (length: 47772 characters)
# Pages included: ['10-K-P60', '10-K-P12', '10-Q-P33', '10-Q-P35', '10-K-P57', '10-K-P52', '10-K-P32', '10-K-P10', '10-K-P58', '10-Q-P29']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 6577 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Cash provided by operating activities was $1.0 billion for the nine months ended September 30, 2025, compared to cash provided by operating activities of $1.5 billion for the nine months ended September 30, 2024. The decrease in cash provided by operating act...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 10
#   - Upside Thesis points: 4
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 6: Capital Allocation & Investment Discipline for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: capital allocation, investment priorities, acquisitions, divestitures, share repurchases, dividends,...
#   - Semantic Query: How management describes capital allocation priorities, including acquisitions, share repurchases, d...
#   - Min Relevant Pages: 2
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 35
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.478', '0.467', '0.459']
#
# Context built (length: 37340 characters)
# Pages included: ['10-K-P60', '10-K-P12', '10-Q-P33', '10-K-P23', '10-Q-P35', '10-Q-P38', '10-K-P49', '10-K-P84', '10-K-P54', '10-K-P87']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 10943 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "For the year ended December 31, 2024, the Company used $42.4 million more cash to invest compared to the prior year ended December 31, 2023, primarily due to $97.8 million more spent on acquisitions, offset by $63.0 million less as a net investment in propert...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 14
#   - Upside Thesis points: 5
#   - Downside Thesis points: 5
#
# ================================================================================
# Running Dimension 7: Balance Sheet Strength & Liquidity for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: balance sheet, liquidity position, leverage, debt maturities, credit facilities, covenant compliance...
#   - Semantic Query: How management discusses liquidity, cash generation, borrowing capacity, and financial flexibility....
#   - Min Relevant Pages: 2
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 32
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.567', '0.556', '0.510']
#
# Context built (length: 44037 characters)
# Pages included: ['10-Q-P35', '10-K-P58', '10-Q-P33', '10-K-P57', '10-Q-P29', '10-K-P30', '10-K-P36', '10-K-P18', '10-K-P22', '10-Q-P25']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 11024 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "As of September 30, 2025, we had no outstanding borrowings under our Revolving Facility, and our net excess borrowing availability was $1.8 billion after being reduced by outstanding letters of credit totaling $79.6 million. Excess availability must equal or ...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 20
#   - Upside Thesis points: 5
#   - Downside Thesis points: 5
#
# ================================================================================
# Running Dimension 8: Operational & Supply Chain Risks for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: supply chain disruption, operational risk, capacity constraints, production issues, labor shortages,...
#   - Semantic Query: Material risks management identifies that could adversely affect operations, margins, liquidity, or ...
#   - Min Relevant Pages: 2
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 4
# Performing semantic vector search...
# Top-k pages selected: 4
# Similarity scores: ['0.521', '0.491', '0.440']
#
# Context built (length: 23316 characters)
# Pages included: ['10-K-P26', '10-K-P22', '10-K-P52', '10-K-P8']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 10238 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Product shortages, loss of key suppliers, and our dependence on third-party suppliers and manufacturers could affect our financial health. Our ability to offer a wide variety of products to our customers is dependent upon our ability to obtain adequate produc...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 6
#   - Upside Thesis points: 6
#   - Downside Thesis points: 5
#
# ================================================================================
# Running Dimension 9: Market, Macro & Regulatory Exposure for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: macroeconomic conditions, interest rates, inflationary pressures, regulatory environment, government...
#   - Semantic Query: What management discloses about this dimension, including key drivers, constraints, risks, and impli...
#   - Min Relevant Pages: 2
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 14
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.491', '0.454', '0.448']
#
# Context built (length: 47736 characters)
# Pages included: ['10-K-P38', '10-K-P62', '10-K-P20', '10-K-P34', '10-K-P22', '10-K-P32', '10-K-P50', '10-K-P57', '10-K-P52', '10-Q-P36']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 15448 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Unstable global economic conditions and geopolitical conflicts may have serious adverse consequences on our business, financial condition, and operations. We are operating in an uncertain economic environment. The global credit and financial markets have expe...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 8
#   - Upside Thesis points: 8
#   - Downside Thesis points: 8
#
# ================================================================================
# Running Dimension 10: Management Strategy & Execution for BLDR company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: management strategy, strategic priorities, execution plan, restructuring, transformation initiatives...
#   - Semantic Query: What management discloses about this dimension, including key drivers, constraints, risks, and impli...
#   - Min Relevant Pages: 2
#
# Total pages available: 169
# Applying keyword filter...
# Pages after keyword filter: 1
# Performing semantic vector search...
# Top-k pages selected: 1
# Similarity scores: ['0.438']
# ⚠️ Insufficient pages (1 < 2). Skipping LLM call.
#
# ================================================================================
# ✓ Saved JSON to: ./output\BLDR_upside_downside_thesis.json
# ✓ Saved Excel to: ./output\BLDR_upside_downside_thesis.xlsx
# ================================================================================
#
# ================================================================================
# USAGE METRICS & COST SUMMARY
# ================================================================================
#
# 📊 API CALLS:
#   • LLM Calls (Chat):        10
#   • Embedding Calls:         9
#   • Total API Calls:         19
#
# 🔢 TOKEN USAGE:
#   • Prompt Tokens:           112,793
#   • Completion Tokens:       17,554
#   • Embedding Tokens:        62,725
#   • Total LLM Tokens:        130,347
#   • Grand Total Tokens:      193,072
#
# ⏱️  EXECUTION TIME:
#   • Total Duration:          3m 2s (182.8s)
#   • Avg per LLM Call:        18.3s
#
# 💰 ESTIMATED COST (Azure OpenAI):
#   • LLM Input:               $0.0338
#   • LLM Output:              $0.0211
#   • Embeddings:              $0.0013
#   • TOTAL COST:              $0.0562
#
# 📈 EFFICIENCY METRICS:
#   • Embedding Cache Hits:    81 unique texts cached
#   • Tokens per LLM Call:     13035 avg
#   • Cost per LLM Call:       $0.0055 avg
# ================================================================================
#
# 💾 Metrics saved to: ./output\BLDR_usage_metrics_20251225_120719.txt
#
#
# ================================================================================
# FINAL UPSIDE THESIS / DOWNSIDE THESIS SUMMARY
# ================================================================================
#
# 📈 UPSIDE THESIS:
# --------------------------------------------------------------------------------
# • The company’s focus on exceptional customer service, broad product offerings, and competitive pricing, combined with a skilled local sales force advising homebuilders on cost reduction and efficiency, positions it to build strong customer relationships and generate new business.
# • The fragmented market presents substantial acquisition opportunities, and the company’s proven ability to integrate acquisitions and expand product offerings allows it to quickly scale and leverage local customer relationships, enhancing competitive positioning.
# • The national manufacturing footprint and emphasis on higher margin value-added products address growing demand for efficient homebuilding solutions, enabling the company to capture above-market growth and become a preferred distributor for large and custom homebuilders.
# • The company maintains a strong liquidity position with $2.1 billion available from cash and borrowing capacity, and no outstanding borrowings under its Revolving Facility as of September 30, 2025, providing financial flexibility.
# • The company’s disciplined capital allocation strategy, including a focus on strategic acquisitions in fragmented markets and a history of significant share repurchases, suggests a proactive approach to growth, value creation, and shareholder returns.
#
# 📉 DOWNSIDE THESIS:
# --------------------------------------------------------------------------------
# • The highly fragmented and competitive nature of the market, with low barriers to entry, means the company faces ongoing competition from local, regional, and national players, which could pressure margins and market share.
# • The company’s growth strategy depends heavily on successful acquisitions and integration; failure to identify suitable acquisition targets or to integrate them effectively could limit growth and adversely affect financial performance.
# • The company’s exposure to unstable global economic conditions and geopolitical conflicts, including unpredictable impacts on commodity and energy prices, supply chains, and financial markets, poses significant risks that could materially harm business operations and financial condition.
# • The company’s gross margins are negatively impacted by shifts in sales mix towards lower margin segments such as large single-family homebuilders and commodity lumber products, coupled with recent margin compression and increased operating expenses, which could pressure profitability.
# • Failure to attract and retain key employees, including senior management, combined with labor shortages and potential unionization, could impair execution of business plans, increase operating costs, and reduce revenue.
#
# ================================================================================
# Running Dimension 1: Business Model & Competitive Position for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: business model, core operations, operating model, revenue model, asset portfolio, operating assets, ...
#   - Semantic Query: How the company describes its business model, competitive advantages, scale, customer value proposit...
#   - Min Relevant Pages: 3
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 68
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.360', '0.352', '0.351']
#
# Context built (length: 44302 characters)
# Pages included: ['10-K-P25', '10-K-P67', '10-K-P153', '10-K-P27', '10-Q-P85', '10-K-P45', '10-K-P136', '10-K-P150', '10-K-P13', '10-K-P42']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 13009 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "We are the nation’s largest producer of reliable, emissions-free energy and a leading energy supplier to businesses, homes and public sector customers nationwide, including three-fourths of Fortune 100 companies. Our nuclear, hydro, wind, and solar generation...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 13
#   - Upside Thesis points: 5
#   - Downside Thesis points: 5
#
# ================================================================================
# Running Dimension 2: Revenue Growth Drivers & Demand Outlook for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: revenue drivers, demand trends, backlog, bookings, pipeline visibility, organic growth, customer dem...
#   - Semantic Query: What factors management identifies as driving or constraining growth, including demand trends, prici...
#   - Min Relevant Pages: 3
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 8
# Performing semantic vector search...
# Top-k pages selected: 8
# Similarity scores: ['0.351', '0.329', '0.322']
#
# Context built (length: 36324 characters)
# Pages included: ['10-Q-P87', '10-K-P25', '10-K-P24', '10-K-P110', '10-K-P192', '10-K-P67', '10-K-P33', '10-Q-P40']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 11626 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "We recently launched Constellation Navigator, which delivers customized paths and sustainable solutions for customers to set and meet their environmental and operational goals. Driven by advanced technology platforms and experienced advisors, it provides stra...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 11
#   - Upside Thesis points: 6
#   - Downside Thesis points: 7
#
# ================================================================================
# Running Dimension 3: Pricing Power & Revenue Quality for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: pricing power, price increases, pricing actions, contract terms, recurring revenue, customer mix, re...
#   - Semantic Query: What factors management identifies as driving or constraining top-line growth, including demand, pri...
#   - Min Relevant Pages: 2
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 4
# Performing semantic vector search...
# Top-k pages selected: 4
# Similarity scores: ['0.323', '0.306', '0.288']
#
# Context built (length: 18959 characters)
# Pages included: ['10-K-P22', '10-Q-P66', '10-K-P213', '10-K-P78']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 4688 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Retail customer renewal rates have been strong over the last nine years across C&I power customer groups with average contract terms of approximately two years and customer duration of approximately five years, with many customers well beyond these metrics. S...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 5
#   - Upside Thesis points: 4
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 4: Margins & Cost Structure for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: gross margin, operating margin, operating income, cost structure, operating expenses, cost drivers, ...
#   - Semantic Query: What factors management cites as affecting gross or operating margins, including pricing, cost infla...
#   - Min Relevant Pages: 2
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 9
# Performing semantic vector search...
# Top-k pages selected: 9
# Similarity scores: ['0.354', '0.346', '0.327']
#
# Context built (length: 28147 characters)
# Pages included: ['10-K-P99', '10-Q-P83', '10-Q-P72', '10-K-P138', '10-K-P86', '10-Q-P10', '10-Q-P16', '10-K-P130', '10-K-P123']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 6033 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Operating revenues $ 23,568 $ 24,918 $ (1,350) Operating expenses Purchased power and fuel 11,419 16,001 (4,582) Operating and maintenance 6,159 5,685 474 Depreciation and amortization 1,123 1,096 27 Taxes other than income taxes 586 553 33 Total operating ex...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 7
#   - Upside Thesis points: 4
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 5: Cash Flow Generation for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: operating cash flow, free cash flow, cash conversion, working capital, capital intensity, cash gener...
#   - Semantic Query: How management describes capital allocation priorities, including acquisitions, share repurchases, d...
#   - Min Relevant Pages: 2
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 10
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.447', '0.411', '0.409']
#
# Context built (length: 40616 characters)
# Pages included: ['10-Q-P83', '10-Q-P84', '10-K-P104', '10-K-P100', '10-K-P99', '10-K-P203', '10-K-P228', '10-Q-P59', '10-Q-P9', '10-K-P12']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 10825 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Our operating and capital expenditures requirements are provided by internally generated cash flows from operations as well as funds from external sources in the capital markets and through bank borrowings. Our business is capital intensive and requires consi...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 8
#   - Upside Thesis points: 3
#   - Downside Thesis points: 3
#
# ================================================================================
# Running Dimension 6: Capital Allocation & Investment Discipline for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: capital allocation, investment priorities, acquisitions, divestitures, share repurchases, dividends,...
#   - Semantic Query: How management describes capital allocation priorities, including acquisitions, share repurchases, d...
#   - Min Relevant Pages: 2
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 54
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.468', '0.447', '0.436']
#
# Context built (length: 36812 characters)
# Pages included: ['10-Q-P55', '10-Q-P83', '10-K-P101', '10-K-P71', '10-Q-P84', '10-K-P104', '10-Q-P93', '10-K-P222', '10-Q-P92', '10-K-P144']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 10553 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Since 2023, our Board of Directors authorized the repurchase of up to $3 billion of the Company's outstanding common stock. As of September 30, 2025, there was approximately $593 million of remaining authority to repurchase shares of the Company's outstanding...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 18
#   - Upside Thesis points: 4
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 7: Balance Sheet Strength & Liquidity for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: balance sheet, liquidity position, leverage, debt maturities, credit facilities, covenant compliance...
#   - Semantic Query: How management discusses liquidity, cash generation, borrowing capacity, and financial flexibility....
#   - Min Relevant Pages: 2
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 87
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.554', '0.509', '0.500']
#
# Context built (length: 42590 characters)
# Pages included: ['10-Q-P83', '10-Q-P85', '10-Q-P45', '10-Q-P84', '10-Q-P90', '10-K-P199', '10-K-P43', '10-K-P99', '10-Q-P86', '10-K-P113']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 16921 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Our operating and capital expenditures requirements are provided by internally generated cash flows from operations as well as funds from external sources in the capital markets and through bank borrowings. Our business is capital intensive and requires consi...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 16
#   - Upside Thesis points: 6
#   - Downside Thesis points: 6
#
# ================================================================================
# Running Dimension 8: Operational & Supply Chain Risks for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: supply chain disruption, operational risk, capacity constraints, production issues, labor shortages,...
#   - Semantic Query: Material risks management identifies that could adversely affect operations, margins, liquidity, or ...
#   - Min Relevant Pages: 2
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 3
# Performing semantic vector search...
# Top-k pages selected: 3
# Similarity scores: ['0.433', '0.395', '0.359']
#
# Context built (length: 15760 characters)
# Pages included: ['10-K-P49', '10-K-P51', '10-K-P50']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 5346 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Capacity factors for nuclear generating units significantly affect our results of operations. Lower capacity factors could decrease our revenues and increase operating costs by requiring us to produce additional energy from our natural gas and oil-fueled faci...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 6
#   - Upside Thesis points: 2
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 9: Market, Macro & Regulatory Exposure for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: macroeconomic conditions, interest rates, inflationary pressures, regulatory environment, government...
#   - Semantic Query: What management discloses about this dimension, including key drivers, constraints, risks, and impli...
#   - Min Relevant Pages: 2
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 17
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.496', '0.472', '0.468']
#
# Context built (length: 41540 characters)
# Pages included: ['10-Q-P86', '10-K-P38', '10-K-P115', '10-Q-P91', '10-K-P43', '10-Q-P90', '10-Q-P41', '10-K-P190', '10-K-P78', '10-K-P193']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 12897 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "We operate in a complex market and regulatory environment that involves significant risks, many of which are beyond our direct control. Such risks, which could negatively affect our consolidated financial statements, fall primarily under the categories below:...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 10
#   - Upside Thesis points: 4
#   - Downside Thesis points: 6
#
# ================================================================================
# Running Dimension 10: Management Strategy & Execution for CEG company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: management strategy, strategic priorities, execution plan, restructuring, transformation initiatives...
#   - Semantic Query: What management discloses about this dimension, including key drivers, constraints, risks, and impli...
#   - Min Relevant Pages: 2
#
# Total pages available: 348
# Applying keyword filter...
# Pages after keyword filter: 3
# Performing semantic vector search...
# Top-k pages selected: 3
# Similarity scores: ['0.371', '0.362', '0.326']
#
# Context built (length: 12436 characters)
# Pages included: ['10-K-P59', '10-K-P219', '10-K-P217']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 8485 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Overall, our company has implemented tactical processes for assessing, identifying, and managing material risks from cybersecurity threats to the company including governance at the Board level and accountability in our executive management for the execution ...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 9
#   - Upside Thesis points: 8
#   - Downside Thesis points: 7
#
# ================================================================================
# ✓ Saved JSON to: ./output\CEG_upside_downside_thesis.json
# ✓ Saved Excel to: ./output\CEG_upside_downside_thesis.xlsx
# ================================================================================
#
# ================================================================================
# USAGE METRICS & COST SUMMARY
# ================================================================================
#
# 📊 API CALLS:
#   • LLM Calls (Chat):        11
#   • Embedding Calls:         10
#   • Total API Calls:         21
#
# 🔢 TOKEN USAGE:
#   • Prompt Tokens:           115,101
#   • Completion Tokens:       20,267
#   • Embedding Tokens:        146,360
#   • Total LLM Tokens:        135,368
#   • Grand Total Tokens:      281,728
#
# ⏱️  EXECUTION TIME:
#   • Total Duration:          3m 32s (212.7s)
#   • Avg per LLM Call:        19.3s
#
# 💰 ESTIMATED COST (Azure OpenAI):
#   • LLM Input:               $0.0345
#   • LLM Output:              $0.0243
#   • Embeddings:              $0.0029
#   • TOTAL COST:              $0.0618
#
# 📈 EFFICIENCY METRICS:
#   • Embedding Cache Hits:    257 unique texts cached
#   • Tokens per LLM Call:     12306 avg
#   • Cost per LLM Call:       $0.0054 avg
# ================================================================================
#
# 💾 Metrics saved to: ./output\CEG_usage_metrics_20251225_121051.txt
#
#
# ================================================================================
# FINAL UPSIDE THESIS / DOWNSIDE THESIS SUMMARY
# ================================================================================
#
# 📈 UPSIDE THESIS:
# --------------------------------------------------------------------------------
# • The company’s position as the nation’s largest producer of reliable, emissions-free energy with a nearly 90% carbon-free generation fleet and a broad customer base, including major corporations, provides a strong competitive advantage and foundation for growth in the clean energy transition.
# • The integrated business model selling electricity, natural gas, and sustainable solutions across multiple regions and customer types offers diversified revenue streams and cross-selling opportunities, enhancing growth potential.
# • The company’s disciplined risk management, including commodity price hedging and eligibility for the nuclear production tax credit (PTC), supports financial stability and earnings predictability.
# • Strong retail customer renewal rates and long-term contracts, such as the 20-year PPA with Meta Platforms, underpin durable revenue streams and effective pricing power.
# • The company maintains substantial liquidity and access to capital markets, with $9.5 billion in credit facilities and a disciplined capital allocation strategy including a significant share repurchase program, supporting funding for capital expenditures, acquisitions, dividends, and debt repayments.
#
# 📉 DOWNSIDE THESIS:
# --------------------------------------------------------------------------------
# • The company’s reliance on carbon-free generation assets exposes it to regulatory, operational, and market risks, including complexities in nuclear fuel supply chains and geopolitical risks related to uranium contracts sourced from Russia.
# • Emerging technologies in distributed generation, energy storage, and energy efficiency could disrupt current business models and render portions of generation assets uneconomic before the end of their useful lives, potentially leading to impairments or accelerated costs.
# • The competitive retail environment with low barriers to entry and aggressive competitors during periods of low natural gas and power prices may pressure margins and limit volume growth.
# • The business’s capital-intensive nature and dependence on external financing expose it to risks from credit rating downgrades, capital market disruptions, and increased collateral requirements that could strain liquidity and increase borrowing costs.
# • Environmental liabilities, including significant remediation costs at legacy sites and uncertainties related to spent nuclear fuel storage timelines, pose substantial financial exposure and legal risks.
#
# ================================================================================
# Running Dimension 1: Business Model & Competitive Position for CSW company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: business model, core operations, operating model, revenue model, asset portfolio, operating assets, ...
#   - Semantic Query: How the company describes its business model, competitive advantages, scale, customer value proposit...
#   - Min Relevant Pages: 3
#
# Total pages available: 199
# Applying keyword filter...
# Pages after keyword filter: 32
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.477', '0.425', '0.400']
#
# Context built (length: 47557 characters)
# Pages included: ['10-K-P13', '10-K-P14', '10-K-P9', '10-K-P49', '10-K-P22', '10-K-P54', '10-Q-P40', '10-K-P60', '10-K-P24', '10-K-P4']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 14361 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "CSWI is a diversified industrial growth company with a strategic focus on providing niche, value-added products in the end markets we serve. We operate in three business segments: Contractor Solutions, Specialized Reliability Solutions and Engineered Building...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 11
#   - Upside Thesis points: 7
#   - Downside Thesis points: 7
#
# ================================================================================
# Running Dimension 2: Revenue Growth Drivers & Demand Outlook for CSW company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: revenue drivers, demand trends, backlog, bookings, pipeline visibility, organic growth, customer dem...
#   - Semantic Query: What factors management identifies as driving or constraining growth, including demand trends, prici...
#   - Min Relevant Pages: 3
#
# Total pages available: 199
# Applying keyword filter...
# Pages after keyword filter: 10
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.460', '0.372', '0.337']
#
# Context built (length: 46703 characters)
# Pages included: ['10-K-P30', '10-K-P49', '10-K-P13', '10-K-P14', '10-K-P54', '10-Q-P40', '10-Q-P42', '10-K-P61', '10-Q-P11', '10-K-P4']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 9185 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "We rely on both organic growth and inorganic growth through acquisitions to provide an increasingly broad portfolio of performance optimizing solutions that meet our customers’ ever-changing needs. We have a successful record of making attractive, synergistic...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 12
#   - Upside Thesis points: 6
#   - Downside Thesis points: 5
#
# ================================================================================
# Running Dimension 3: Pricing Power & Revenue Quality for CSW company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: pricing power, price increases, pricing actions, contract terms, recurring revenue, customer mix, re...
#   - Semantic Query: What factors management identifies as driving or constraining top-line growth, including demand, pri...
#   - Min Relevant Pages: 2
#
# Total pages available: 199
# Applying keyword filter...
# Pages after keyword filter: 11
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.421', '0.408', '0.378']
#
# Context built (length: 43525 characters)
# Pages included: ['10-K-P26', '10-K-P24', '10-K-P49', '10-Q-P47', '10-Q-P43', '10-K-P60', '10-K-P55', '10-Q-P42', '10-Q-P40', '10-Q-P49']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 5736 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "We may be unable to pass along price increases to our customers, which could have a material adverse effect on our business and results of operations.",
#       "source_section": "10-K Item 1A"
#     },
#     {
#       "statement": "We rely on independent distributor...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 9
#   - Upside Thesis points: 3
#   - Downside Thesis points: 3
#
# ================================================================================
# Running Dimension 4: Margins & Cost Structure for CSW company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: gross margin, operating margin, operating income, cost structure, operating expenses, cost drivers, ...
#   - Semantic Query: What factors management cites as affecting gross or operating margins, including pricing, cost infla...
#   - Min Relevant Pages: 2
#
# Total pages available: 199
# Applying keyword filter...
# Pages after keyword filter: 26
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.448', '0.439', '0.428']
#
# Context built (length: 41527 characters)
# Pages included: ['10-K-P26', '10-Q-P43', '10-K-P56', '10-K-P22', '10-Q-P56', '10-K-P84', '10-Q-P45', '10-K-P40', '10-Q-P47', '10-K-P63']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 10421 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Macroeconomic conditions have caused supply chains for many companies to be interrupted, slowed or temporarily rendered inoperable. In addition, supply chain shortages and cost increases due to new or increased tariffs have negatively impacted, and could cont...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 12
#   - Upside Thesis points: 5
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 5: Cash Flow Generation for CSW company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: operating cash flow, free cash flow, cash conversion, working capital, capital intensity, cash gener...
#   - Semantic Query: How management describes capital allocation priorities, including acquisitions, share repurchases, d...
#   - Min Relevant Pages: 2
#
# Total pages available: 199
# Applying keyword filter...
# Pages after keyword filter: 17
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.457', '0.430', '0.430']
#
# Context built (length: 42633 characters)
# Pages included: ['10-K-P30', '10-K-P32', '10-Q-P50', '10-K-P63', '10-K-P65', '10-Q-P52', '10-K-P129', '10-Q-P15', '10-Q-P14', '10-K-P94']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 6267 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Our ability to consistently generate strong cash flow from our operations is one of our most significant financial strengths: it enables us to invest in our people and our brands, make capital investments and strategic acquisitions, provide a cash dividend pr...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 12
#   - Upside Thesis points: 4
#   - Downside Thesis points: 3
#
# ================================================================================
# Running Dimension 6: Capital Allocation & Investment Discipline for CSW company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: capital allocation, investment priorities, acquisitions, divestitures, share repurchases, dividends,...
#   - Semantic Query: How management describes capital allocation priorities, including acquisitions, share repurchases, d...
#   - Min Relevant Pages: 2
#
# Total pages available: 199
# Applying keyword filter...
# Pages after keyword filter: 45
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.457', '0.450', '0.442']
#
# Context built (length: 46599 characters)
# Pages included: ['10-K-P30', '10-Q-P54', '10-K-P66', '10-K-P32', '10-Q-P50', '10-Q-P29', '10-K-P63', '10-K-P112', '10-Q-P24', '10-K-P65']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 7880 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Our ability to consistently generate strong cash flow from our operations is one of our most significant financial strengths: it enables us to invest in our people and our brands, make capital investments and strategic acquisitions, provide a cash dividend pr...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 7
#   - Upside Thesis points: 4
#   - Downside Thesis points: 3
#
# ================================================================================
# Running Dimension 7: Balance Sheet Strength & Liquidity for CSW company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: balance sheet, liquidity position, leverage, debt maturities, credit facilities, covenant compliance...
#   - Semantic Query: How management discusses liquidity, cash generation, borrowing capacity, and financial flexibility....
#   - Min Relevant Pages: 2
#
# Total pages available: 199
# Applying keyword filter...
# Pages after keyword filter: 31
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.493', '0.462', '0.461']
#
# Context built (length: 43268 characters)
# Pages included: ['10-Q-P54', '10-Q-P24', '10-K-P32', '10-Q-P26', '10-Q-P27', '10-K-P107', '10-K-P30', '10-K-P87', '10-Q-P31', '10-K-P105']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 8513 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "As of September 30, 2025 and March 31, 2025, we had $60.0 million and $0.0 million, respectively, in our outstanding balance, which resulted in borrowing capacity under the Revolving Credit Facility of $638.7 million and $498.7 million, respectively, net of c...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 11
#   - Upside Thesis points: 8
#   - Downside Thesis points: 6
#
# ================================================================================
# Running Dimension 8: Operational & Supply Chain Risks for CSW company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: supply chain disruption, operational risk, capacity constraints, production issues, labor shortages,...
#   - Semantic Query: Material risks management identifies that could adversely affect operations, margins, liquidity, or ...
#   - Min Relevant Pages: 2
#
# Total pages available: 199
# Applying keyword filter...
# Pages after keyword filter: 3
# Performing semantic vector search...
# Top-k pages selected: 3
# Similarity scores: ['0.556', '0.550', '0.527']
#
# Context built (length: 16601 characters)
# Pages included: ['10-K-P30', '10-K-P24', '10-K-P26']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 8699 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "The challenge to attract and retain qualified talent in the current competitive labor market could lead to increased wage inflation or impede our ability to execute certain key strategic initiatives as we respond to labor shortages. Failure to successfully at...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 7
#   - Upside Thesis points: 7
#   - Downside Thesis points: 7
#
# ================================================================================
# Running Dimension 9: Market, Macro & Regulatory Exposure for CSW company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: macroeconomic conditions, interest rates, inflationary pressures, regulatory environment, government...
#   - Semantic Query: What management discloses about this dimension, including key drivers, constraints, risks, and impli...
#   - Min Relevant Pages: 2
#
# Total pages available: 199
# Applying keyword filter...
# Pages after keyword filter: 16
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.513', '0.488', '0.476']
#
# Context built (length: 53421 characters)
# Pages included: ['10-Q-P56', '10-K-P40', '10-K-P71', '10-K-P32', '10-K-P28', '10-K-P26', '10-K-P49', '10-K-P87', '10-K-P19', '10-K-P81']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 17332 chars)
# ...
#
# Total pages available: 304
# Applying keyword filter...
# Pages after keyword filter: 2
# Performing semantic vector search...
# Top-k pages selected: 2
# Similarity scores: ['0.336', '0.325']
# ⚠️ Insufficient pages (2 < 3). Skipping LLM call.
#
# ================================================================================
# Running Dimension 3: Pricing Power & Revenue Quality for TRGP company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: pricing power, price increases, pricing actions, contract terms, recurring revenue, customer mix, re...
#   - Semantic Query: What factors management identifies as driving or constraining top-line growth, including demand, pri...
#   - Min Relevant Pages: 2
#
# Total pages available: 304
# Applying keyword filter...
# Pages after keyword filter: 7
# Performing semantic vector search...
# Top-k pages selected: 7
# Similarity scores: ['0.444', '0.423', '0.395']
#
# Context built (length: 34372 characters)
# Pages included: ['10-K-P101', '10-K-P97', '10-K-P99', '10-Q-P45', '10-K-P18', '10-Q-P31', '10-K-P221']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 9424 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Our profitability is also impacted by fee-based contracts. Our growing capital expenditures for pipelines and gathering and processing assets underpinned by fee-based margin, expansion of our Downstream facilities, continued focus on adding fee-based margin t...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 10
#   - Upside Thesis points: 5
#   - Downside Thesis points: 5
#
# ================================================================================
# Running Dimension 4: Margins & Cost Structure for TRGP company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: gross margin, operating margin, operating income, cost structure, operating expenses, cost drivers, ...
#   - Semantic Query: What factors management cites as affecting gross or operating margins, including pricing, cost infla...
#   - Min Relevant Pages: 2
#
# Total pages available: 304
# Applying keyword filter...
# Pages after keyword filter: 32
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.490', '0.459', '0.459']
#
# Context built (length: 48571 characters)
# Pages included: ['10-K-P101', '10-Q-P47', '10-K-P103', '10-Q-P49', '10-K-P97', '10-K-P99', '10-K-P105', '10-K-P48', '10-K-P69', '10-Q-P56']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 13039 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Our profitability is a function of the difference between: (i) the revenues we receive from our operations, including fee-based revenues from services and revenues from the natural gas, NGLs, crude oil and condensate we sell, and (ii) the costs associated wit...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 20
#   - Upside Thesis points: 5
#   - Downside Thesis points: 5
#
# ================================================================================
# Running Dimension 5: Cash Flow Generation for TRGP company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: operating cash flow, free cash flow, cash conversion, working capital, capital intensity, cash gener...
#   - Semantic Query: How management describes capital allocation priorities, including acquisitions, share repurchases, d...
#   - Min Relevant Pages: 2
#
# Total pages available: 304
# Applying keyword filter...
# Pages after keyword filter: 22
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.423', '0.412', '0.409']
#
# Context built (length: 44587 characters)
# Pages included: ['10-K-P75', '10-K-P105', '10-K-P211', '10-K-P101', '10-K-P186', '10-Q-P47', '10-Q-P60', '10-K-P217', '10-K-P106', '10-Q-P50']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 7793 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Adjusted EBITDA is used as a supplemental financial measure by us and by external users of our financial statements such as investors, commercial banks and others to measure the ability of our assets to generate cash sufficient to pay interest costs, support ...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 10
#   - Upside Thesis points: 4
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 6: Capital Allocation & Investment Discipline for TRGP company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: capital allocation, investment priorities, acquisitions, divestitures, share repurchases, dividends,...
#   - Semantic Query: How management describes capital allocation priorities, including acquisitions, share repurchases, d...
#   - Min Relevant Pages: 2
#
# Total pages available: 304
# Applying keyword filter...
# Pages after keyword filter: 55
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.454', '0.436', '0.429']
#
# Context built (length: 44092 characters)
# Pages included: ['10-K-P121', '10-K-P65', '10-K-P119', '10-K-P176', '10-K-P75', '10-K-P178', '10-K-P182', '10-K-P96', '10-K-P105', '10-K-P167']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 6456 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "The increase in total growth capital expenditures was primarily due to system expansions in the Permian region in response to forecasted production growth and higher activity levels, and expansions in our downstream business. The increase in total maintenance...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 6
#   - Upside Thesis points: 5
#   - Downside Thesis points: 5
#
# ================================================================================
# Running Dimension 7: Balance Sheet Strength & Liquidity for TRGP company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: balance sheet, liquidity position, leverage, debt maturities, credit facilities, covenant compliance...
#   - Semantic Query: How management discusses liquidity, cash generation, borrowing capacity, and financial flexibility....
#   - Min Relevant Pages: 2
#
# Total pages available: 304
# Applying keyword filter...
# Pages after keyword filter: 43
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.489', '0.481', '0.453']
#
# Context built (length: 45278 characters)
# Pages included: ['10-K-P113', '10-Q-P58', '10-K-P173', '10-K-P178', '10-K-P166', '10-K-P119', '10-K-P176', '10-K-P18', '10-Q-P66', '10-Q-P64']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 11326 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "As of December 31, 2024, inclusive of our consolidated joint venture accounts, we had $157.3 million of Cash and cash equivalents on our Consolidated Balance Sheets. On a consolidated basis, our main sources of liquidity and capital resources are internally g...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 16
#   - Upside Thesis points: 4
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 8: Operational & Supply Chain Risks for TRGP company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: supply chain disruption, operational risk, capacity constraints, production issues, labor shortages,...
#   - Semantic Query: Material risks management identifies that could adversely affect operations, margins, liquidity, or ...
#   - Min Relevant Pages: 2
#
# Total pages available: 304
# Applying keyword filter...
# Pages after keyword filter: 3
# Performing semantic vector search...
# Top-k pages selected: 3
# Similarity scores: ['0.510', '0.459', '0.413']
#
# Context built (length: 15624 characters)
# Pages included: ['10-K-P46', '10-K-P58', '10-K-P29']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 8481 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "We operate in areas of high industry activity, which may affect our ability to hire, train or retain qualified personnel needed to manage and operate our business.",
#       "source_section": "10-K Item 1A"
#     },
#     {
#       "statement": "If third-party pipeli...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 14
#   - Upside Thesis points: 3
#   - Downside Thesis points: 5
#
# ================================================================================
# Running Dimension 9: Market, Macro & Regulatory Exposure for TRGP company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: macroeconomic conditions, interest rates, inflationary pressures, regulatory environment, government...
#   - Semantic Query: What management discloses about this dimension, including key drivers, constraints, risks, and impli...
#   - Min Relevant Pages: 2
#
# Total pages available: 304
# Applying keyword filter...
# Pages after keyword filter: 19
# Performing semantic vector search...
# Top-k pages selected: 10
# Similarity scores: ['0.499', '0.476', '0.450']
#
# Context built (length: 52997 characters)
# Pages included: ['10-K-P48', '10-K-P75', '10-K-P121', '10-Q-P66', '10-K-P123', '10-K-P119', '10-K-P67', '10-K-P125', '10-K-P101', '10-K-P50']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 11542 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "Inflationary issues and associated changes in monetary policy have resulted in and may result in additional increases to the cost of our goods, services and personnel, which in turn cause our capital expenditures and operating costs to rise.",
#       "source_s...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 20
#   - Upside Thesis points: 4
#   - Downside Thesis points: 4
#
# ================================================================================
# Running Dimension 10: Management Strategy & Execution for TRGP company
# ================================================================================
# Retrieval Config:
#   - Keyword Filter: management strategy, strategic priorities, execution plan, restructuring, transformation initiatives...
#   - Semantic Query: What management discloses about this dimension, including key drivers, constraints, risks, and impli...
#   - Min Relevant Pages: 2
#
# Total pages available: 304
# Applying keyword filter...
# Pages after keyword filter: 2
# Performing semantic vector search...
# Top-k pages selected: 2
# Similarity scores: ['0.399', '0.381']
#
# Context built (length: 9239 characters)
# Pages included: ['10-K-P77', '10-K-P91']
#
# Calling Azure OpenAI with enhanced prompt...
#
# Response received (length: 7664 chars)
# Response preview:
# {
#   "facts": [
#     {
#       "statement": "We may be able to incur substantial additional indebtedness in the future. The New TRGP Revolver provides an available commitment of $3.5 billion, with a requirement to maintain a minimum available borrowing capacity equal to the aggregate amount outstanding ...
#
# ✓ Successfully parsed JSON:
#   - Facts extracted: 8
#   - Upside Thesis points: 4
#   - Downside Thesis points: 3
#
# ================================================================================
# ✓ Saved JSON to: ./output\TRGP_upside_downside_thesis.json
# ✓ Saved Excel to: ./output\TRGP_upside_downside_thesis.xlsx
# ================================================================================
#
# ================================================================================
# USAGE METRICS & COST SUMMARY
# ================================================================================
#
# 📊 API CALLS:
#   • LLM Calls (Chat):        10
#   • Embedding Calls:         10
#   • Total API Calls:         20
#
# 🔢 TOKEN USAGE:
#   • Prompt Tokens:           114,327
#   • Completion Tokens:       17,950
#   • Embedding Tokens:        129,051
#   • Total LLM Tokens:        132,277
#   • Grand Total Tokens:      261,328
#
# ⏱️  EXECUTION TIME:
#   • Total Duration:          3m 23s (203.7s)
#   • Avg per LLM Call:        20.4s
#
# 💰 ESTIMATED COST (Azure OpenAI):
#   • LLM Input:               $0.0343
#   • LLM Output:              $0.0215
#   • Embeddings:              $0.0026
#   • TOTAL COST:              $0.0584
#
# 📈 EFFICIENCY METRICS:
#   • Embedding Cache Hits:    765 unique texts cached
#   • Tokens per LLM Call:     13228 avg
#   • Cost per LLM Call:       $0.0056 avg
# ================================================================================
#
# 💾 Metrics saved to: ./output\TRGP_usage_metrics_20251225_122851.txt
#
#
# ================================================================================
# FINAL UPSIDE THESIS / DOWNSIDE THESIS SUMMARY
# ================================================================================
#
# 📈 UPSIDE THESIS:
# --------------------------------------------------------------------------------
# • The company’s comprehensive and integrated midstream services, supported by strategically located, high-quality, and technologically advanced assets, provide a strong competitive advantage and position it well to capture demand across gathering, processing, transportation, fractionation, storage, and export markets.
# • Increasing emphasis on fee-based contracts with long-term minimum volume commitments and a diverse contract mix enhances revenue stability and mitigates exposure to commodity price volatility, supported by an effective commodity hedging program.
# • Strong operating cash flow generation, substantial adjusted EBITDA, and disciplined capital expenditure management enable the company to fund growth initiatives while maintaining positive adjusted free cash flow and operational liquidity.
# • The company maintains substantial liquidity and financial flexibility through multiple capital sources, including a $3.5 billion revolving credit facility with potential increases, commercial paper program, and securitization facility, supporting near-term financial stability and growth funding.
# • Active board oversight and dedicated senior management focus on cybersecurity risks, combined with the absence of material prior incidents, demonstrate a robust governance framework and operational resilience.
#
# 📉 DOWNSIDE THESIS:
# --------------------------------------------------------------------------------
# • The company faces intense competition across all segments from major pipeline companies, master limited partnerships, producers, and other midstream providers, which could pressure pricing, market share, and contract terms, especially given some exposure to commodity price volatility through percent-of-proceeds contracts.
# • Significant operational and supply chain risks exist, including hazards that may not be fully insured, aging pipeline infrastructure requiring costly maintenance, potential third-party facility unavailability, labor challenges, and volume variability that could materially impact income and cash flow.
# • Large growth and maintenance capital expenditures relative to cash flow, combined with inflationary pressures and rising operating costs, may constrain free cash flow and margin sustainability if returns do not meet expectations or volumes decline.
# • The company’s substantial outstanding debt and contractual obligations, including restrictive covenants and significant future interest payments, could limit operational flexibility and increase financial risk, with potential default risks if financial ratios are not maintained.
# • Regulatory, market, and macro risks—including commodity price volatility, interest rate increases, climate change regulations, and changing tax laws—pose material threats to cash flows and profitability, while the evolving cybersecurity threat landscape maintains ongoing vulnerability despite governance efforts.
